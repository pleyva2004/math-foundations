# %% [markdown]
# # Math Foundations — Interactive Notebook
#
# Progressive cells across all foundation concepts.
# Open in Colab or Jupyter Lab; run cells top-to-bottom or jump to a section.

# %% [markdown]
# ## Level: Novice (high-school+)

# %% [markdown]
# ### 00: Sets and Functions
#
# **Prereqs:** (none)
#
# The two foundational objects: collections and rules that map elements between them.
#
# See `concepts/00-sets-and-functions.md` for the full concept page.

# %%
"""Sets and Functions — concept 00-sets-and-functions of the math-foundations learning map.

The two foundational objects: collections and rules that map elements between them.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Sets and Functions (concept 00-sets-and-functions)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/00-sets-and-functions.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 01: Logic and Proof
#
# **Prereqs:** 00-sets-and-functions
#
# Propositional and predicate logic, truth tables, the basic proof strategies (direct, contrapositive, contradiction, induction).
#
# See `concepts/01-logic-and-proof.md` for the full concept page.

# %%
"""Logic and Proof — concept 01-logic-and-proof of the math-foundations learning map.

Propositional and predicate logic, truth tables, the basic proof strategies (direct, contrapositive, contradiction, induction).

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Logic and Proof (concept 01-logic-and-proof)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/01-logic-and-proof.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 02: Counting and Combinatorics
#
# **Prereqs:** 00-sets-and-functions
#
# Counting principles: permutations, combinations, the pigeonhole principle, inclusion-exclusion.
#
# See `concepts/02-counting.md` for the full concept page.

# %%
"""Counting and Combinatorics — concept 02-counting of the math-foundations learning map.

Counting principles: permutations, combinations, the pigeonhole principle, inclusion-exclusion.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Counting and Combinatorics (concept 02-counting)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/02-counting.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 03: Relations and Orderings
#
# **Prereqs:** 00-sets-and-functions
#
# Equivalence relations, partial and total orders, equivalence classes.
#
# See `concepts/03-relations-and-orderings.md` for the full concept page.

# %%
"""Relations and Orderings — concept 03-relations-and-orderings of the math-foundations learning map.

Equivalence relations, partial and total orders, equivalence classes.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Relations and Orderings (concept 03-relations-and-orderings)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/03-relations-and-orderings.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Level: Intermediate (calc + linear algebra)

# %% [markdown]
# ### 04: Groups, Rings, Fields
#
# **Prereqs:** 00-sets-and-functions, 01-logic-and-proof
#
# Abstract algebraic structures with binary operations satisfying axioms.
#
# See `concepts/04-groups-rings-fields.md` for the full concept page.

# %%
"""Groups, Rings, Fields — concept 04-groups-rings-fields of the math-foundations learning map.

Abstract algebraic structures with binary operations satisfying axioms.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Groups, Rings, Fields (concept 04-groups-rings-fields)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/04-groups-rings-fields.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 05: Vector Spaces
#
# **Prereqs:** 04-groups-rings-fields
#
# Sets closed under linear combinations over a field; the universal object of linear algebra.
#
# See `concepts/05-vector-spaces.md` for the full concept page.

# %%
"""Vector Spaces — concept 05-vector-spaces of the math-foundations learning map.

Sets closed under linear combinations over a field; the universal object of linear algebra.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Vector Spaces (concept 05-vector-spaces)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/05-vector-spaces.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 06: Linear Maps and Matrices
#
# **Prereqs:** 05-vector-spaces
#
# Structure-preserving functions between vector spaces; the matrix representation.
#
# See `concepts/06-linear-maps.md` for the full concept page.

# %%
"""Linear Maps and Matrices — concept 06-linear-maps of the math-foundations learning map.

Structure-preserving functions between vector spaces; the matrix representation.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Linear Maps and Matrices (concept 06-linear-maps)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/06-linear-maps.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 07: Eigenvalues and Eigenvectors
#
# **Prereqs:** 06-linear-maps
#
# Directions preserved by a linear map up to scaling; the building blocks of spectral analysis.
#
# See `concepts/07-eigenvalues.md` for the full concept page.

# %%
"""Eigenvalues and Eigenvectors — concept 07-eigenvalues of the math-foundations learning map.

Directions preserved by a linear map up to scaling; the building blocks of spectral analysis.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Eigenvalues and Eigenvectors (concept 07-eigenvalues)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/07-eigenvalues.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 08: Inner Product Spaces
#
# **Prereqs:** 05-vector-spaces
#
# Vector spaces equipped with a notion of angle and length via an inner product.
#
# See `concepts/08-inner-product-spaces.md` for the full concept page.

# %%
"""Inner Product Spaces — concept 08-inner-product-spaces of the math-foundations learning map.

Vector spaces equipped with a notion of angle and length via an inner product.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Inner Product Spaces (concept 08-inner-product-spaces)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/08-inner-product-spaces.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 09: Norms and Metrics
#
# **Prereqs:** 05-vector-spaces
#
# Generalised notions of distance; the foundation of analysis on vector spaces.
#
# See `concepts/09-norms-and-metrics.md` for the full concept page.

# %%
"""Norms and Metrics — concept 09-norms-and-metrics of the math-foundations learning map.

Generalised notions of distance; the foundation of analysis on vector spaces.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Norms and Metrics (concept 09-norms-and-metrics)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/09-norms-and-metrics.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Level: Advanced (analysis + probability)

# %% [markdown]
# ### 10: Sequences and Limits
#
# **Prereqs:** 09-norms-and-metrics
#
# Convergence of sequences; the epsilon-N definition; Cauchy sequences and completeness.
#
# See `concepts/10-sequences-and-limits.md` for the full concept page.

# %%
"""Sequences and Limits — concept 10-sequences-and-limits of the math-foundations learning map.

Convergence of sequences; the epsilon-N definition; Cauchy sequences and completeness.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Sequences and Limits (concept 10-sequences-and-limits)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/10-sequences-and-limits.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 11: Continuity
#
# **Prereqs:** 10-sequences-and-limits
#
# The epsilon-delta definition; continuity as preservation of limits; uniform vs pointwise continuity.
#
# See `concepts/11-continuity.md` for the full concept page.

# %%
"""Continuity — concept 11-continuity of the math-foundations learning map.

The epsilon-delta definition; continuity as preservation of limits; uniform vs pointwise continuity.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Continuity (concept 11-continuity)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/11-continuity.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 12: Derivatives (Univariate)
#
# **Prereqs:** 11-continuity
#
# The local linear approximation; the limit of a difference quotient; differentiation rules.
#
# See `concepts/12-derivatives.md` for the full concept page.

# %%
"""Derivatives (Univariate) — concept 12-derivatives of the math-foundations learning map.

The local linear approximation; the limit of a difference quotient; differentiation rules.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Derivatives (Univariate) (concept 12-derivatives)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/12-derivatives.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 13: Multivariate Calculus
#
# **Prereqs:** 12-derivatives
#
# Partial derivatives; the chain rule in multiple variables; directional derivatives.
#
# See `concepts/13-multivariate-calculus.md` for the full concept page.

# %%
"""Multivariate Calculus — concept 13-multivariate-calculus of the math-foundations learning map.

Partial derivatives; the chain rule in multiple variables; directional derivatives.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Multivariate Calculus (concept 13-multivariate-calculus)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/13-multivariate-calculus.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 14: Gradient and Jacobian
#
# **Prereqs:** 13-multivariate-calculus, 06-linear-maps
#
# The gradient as the vector of partial derivatives; the Jacobian as the matrix of partial derivatives of a vector-valued function.
#
# See `concepts/14-gradient-jacobian.md` for the full concept page.

# %%
"""Gradient and Jacobian — concept 14-gradient-jacobian of the math-foundations learning map.

The gradient as the vector of partial derivatives; the Jacobian as the matrix of partial derivatives of a vector-valued function.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Gradient and Jacobian (concept 14-gradient-jacobian)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/14-gradient-jacobian.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 15: Integration (Riemann)
#
# **Prereqs:** 11-continuity
#
# The Riemann integral as a limit of step-function approximations; the fundamental theorem of calculus.
#
# See `concepts/15-integration.md` for the full concept page.

# %%
"""Integration (Riemann) — concept 15-integration of the math-foundations learning map.

The Riemann integral as a limit of step-function approximations; the fundamental theorem of calculus.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Integration (Riemann) (concept 15-integration)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/15-integration.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 16: Series and Convergence
#
# **Prereqs:** 10-sequences-and-limits
#
# Convergence of infinite sums; absolute vs conditional; power series and Taylor expansions.
#
# See `concepts/16-series-and-convergence.md` for the full concept page.

# %%
"""Series and Convergence — concept 16-series-and-convergence of the math-foundations learning map.

Convergence of infinite sums; absolute vs conditional; power series and Taylor expansions.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Series and Convergence (concept 16-series-and-convergence)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/16-series-and-convergence.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 17: Sample Spaces
#
# **Prereqs:** 00-sets-and-functions
#
# The set of all possible outcomes of an experiment; the starting point of probability.
#
# See `concepts/17-sample-spaces.md` for the full concept page.

# %%
"""Sample Spaces — concept 17-sample-spaces of the math-foundations learning map.

The set of all possible outcomes of an experiment; the starting point of probability.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Sample Spaces (concept 17-sample-spaces)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/17-sample-spaces.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 20: Conditional Probability
#
# **Prereqs:** 19-probability-measures
#
# P(A | B) = P(A and B) / P(B); the update rule for new information.
#
# See `concepts/20-conditional-probability.md` for the full concept page.

# %%
"""Conditional Probability — concept 20-conditional-probability of the math-foundations learning map.

P(A | B) = P(A and B) / P(B); the update rule for new information.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Conditional Probability (concept 20-conditional-probability)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/20-conditional-probability.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 21: Independence
#
# **Prereqs:** 20-conditional-probability
#
# P(A and B) = P(A) P(B); events that do not influence each other.
#
# See `concepts/21-independence.md` for the full concept page.

# %%
"""Independence — concept 21-independence of the math-foundations learning map.

P(A and B) = P(A) P(B); events that do not influence each other.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Independence (concept 21-independence)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/21-independence.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 22: Random Variables
#
# **Prereqs:** 19-probability-measures
#
# Measurable functions from the sample space to the real line; the bridge from sets-of-outcomes to numerical values.
#
# See `concepts/22-random-variables.md` for the full concept page.

# %%
"""Random Variables — concept 22-random-variables of the math-foundations learning map.

Measurable functions from the sample space to the real line; the bridge from sets-of-outcomes to numerical values.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Random Variables (concept 22-random-variables)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/22-random-variables.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 23: Probability Distributions
#
# **Prereqs:** 22-random-variables
#
# The full description of a random variable: its cumulative distribution function, its discrete probability mass function, or its continuous probability density function.
#
# See `concepts/23-distributions.md` for the full concept page.

# %%
"""Probability Distributions — concept 23-distributions of the math-foundations learning map.

The full description of a random variable: its cumulative distribution function, its discrete probability mass function, or its continuous probability density function.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Probability Distributions (concept 23-distributions)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/23-distributions.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 24: Probability Density Functions
#
# **Prereqs:** 23-distributions, 15-integration
#
# A non-negative integrable function whose integral over a set gives the probability that a continuous random variable lands in that set.
#
# See `concepts/24-pdf.md` for the full concept page.

# %%
"""Probability Density Functions — concept 24-pdf of the math-foundations learning map.

A non-negative integrable function whose integral over a set gives the probability that a continuous random variable lands in that set.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Probability Density Functions (concept 24-pdf)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/24-pdf.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 25: Expectation
#
# **Prereqs:** 23-distributions, 15-integration
#
# The weighted average of a random variable's values, weighted by their probability; the integral of the random variable against its distribution.
#
# See `concepts/25-expectation.md` for the full concept page.

# %%
"""Expectation — concept 25-expectation of the math-foundations learning map.

The weighted average of a random variable's values, weighted by their probability; the integral of the random variable against its distribution.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Expectation (concept 25-expectation)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/25-expectation.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 26: Variance and Covariance
#
# **Prereqs:** 25-expectation
#
# Second-order moments measuring spread (variance) and linear association (covariance).
#
# See `concepts/26-variance-covariance.md` for the full concept page.

# %%
"""Variance and Covariance — concept 26-variance-covariance of the math-foundations learning map.

Second-order moments measuring spread (variance) and linear association (covariance).

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Variance and Covariance (concept 26-variance-covariance)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/26-variance-covariance.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 28: Change of Variables (Probability)
#
# **Prereqs:** 24-pdf, 14-gradient-jacobian
#
# How densities transform under invertible smooth maps; the Jacobian determinant appears as the volume-correction factor.
#
# See `concepts/28-change-of-variables-probability.md` for the full concept page.

# %%
"""Change of Variables (Probability) — concept 28-change-of-variables-probability of the math-foundations learning map.

How densities transform under invertible smooth maps; the Jacobian determinant appears as the volume-correction factor.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Change of Variables (Probability) (concept 28-change-of-variables-probability)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/28-change-of-variables-probability.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 29: Ordinary Differential Equations
#
# **Prereqs:** 12-derivatives
#
# Equations relating a function to its derivatives; the basic objects of dynamical systems.
#
# See `concepts/29-ode.md` for the full concept page.

# %%
"""Ordinary Differential Equations — concept 29-ode of the math-foundations learning map.

Equations relating a function to its derivatives; the basic objects of dynamical systems.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Ordinary Differential Equations (concept 29-ode)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/29-ode.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 35: Self-Information (Surprisal)
#
# **Prereqs:** 23-distributions
#
# I(x) = -log p(x); the surprise associated with observing an outcome under a probability distribution.
#
# See `concepts/35-self-information.md` for the full concept page.

# %%
"""Self-Information (Surprisal) — concept 35-self-information of the math-foundations learning map.

I(x) = -log p(x); the surprise associated with observing an outcome under a probability distribution.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Self-Information (Surprisal) (concept 35-self-information)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/35-self-information.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 36: Shannon Entropy
#
# **Prereqs:** 35-self-information, 25-expectation
#
# H(X) = E[-log p(X)]; the average information content of a random variable; measures uncertainty.
#
# See `concepts/36-shannon-entropy.md` for the full concept page.

# %%
"""Shannon Entropy — concept 36-shannon-entropy of the math-foundations learning map.

H(X) = E[-log p(X)]; the average information content of a random variable; measures uncertainty.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Shannon Entropy (concept 36-shannon-entropy)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/36-shannon-entropy.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 37: Cross-Entropy
#
# **Prereqs:** 36-shannon-entropy
#
# H(p, q) = -E_p[log q]; the average code-length when using distribution q to encode samples drawn from p.
#
# See `concepts/37-cross-entropy.md` for the full concept page.

# %%
"""Cross-Entropy — concept 37-cross-entropy of the math-foundations learning map.

H(p, q) = -E_p[log q]; the average code-length when using distribution q to encode samples drawn from p.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Cross-Entropy (concept 37-cross-entropy)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/37-cross-entropy.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 38: KL Divergence
#
# **Prereqs:** 37-cross-entropy
#
# D_KL(p || q) = E_p[log p - log q]; the relative entropy / information gain in moving from q to p. Non-symmetric, non-metric.
#
# See `concepts/38-kl-divergence.md` for the full concept page.

# %%
"""KL Divergence — concept 38-kl-divergence of the math-foundations learning map.

D_KL(p || q) = E_p[log p - log q]; the relative entropy / information gain in moving from q to p. Non-symmetric, non-metric.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("KL Divergence (concept 38-kl-divergence)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/38-kl-divergence.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 39: Mutual Information
#
# **Prereqs:** 38-kl-divergence, 21-independence
#
# I(X; Y) = D_KL(p(x,y) || p(x) p(y)); the reduction in uncertainty about X from observing Y.
#
# See `concepts/39-mutual-information.md` for the full concept page.

# %%
"""Mutual Information — concept 39-mutual-information of the math-foundations learning map.

I(X; Y) = D_KL(p(x,y) || p(x) p(y)); the reduction in uncertainty about X from observing Y.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Mutual Information (concept 39-mutual-information)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/39-mutual-information.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Level: Graduate (measure theory + stochastic)

# %% [markdown]
# ### 18: Events and Sigma-Algebras
#
# **Prereqs:** 17-sample-spaces
#
# A sigma-algebra is a collection of subsets closed under complement and countable union; the rigorous basis for which events can be assigned probabilities.
#
# See `concepts/18-sigma-algebras.md` for the full concept page.

# %%
"""Events and Sigma-Algebras — concept 18-sigma-algebras of the math-foundations learning map.

A sigma-algebra is a collection of subsets closed under complement and countable union; the rigorous basis for which events can be assigned probabilities.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Events and Sigma-Algebras (concept 18-sigma-algebras)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/18-sigma-algebras.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 19: Probability Measures
#
# **Prereqs:** 18-sigma-algebras
#
# A function from a sigma-algebra to [0,1] satisfying countable additivity and P(Omega) = 1.
#
# See `concepts/19-probability-measures.md` for the full concept page.

# %%
"""Probability Measures — concept 19-probability-measures of the math-foundations learning map.

A function from a sigma-algebra to [0,1] satisfying countable additivity and P(Omega) = 1.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Probability Measures (concept 19-probability-measures)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/19-probability-measures.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 27: Conditional Expectation
#
# **Prereqs:** 25-expectation, 20-conditional-probability
#
# The expected value of a random variable given the value of another (or given a sub-sigma-algebra); the foundation of regression and martingale theory.
#
# See `concepts/27-conditional-expectation.md` for the full concept page.

# %%
"""Conditional Expectation — concept 27-conditional-expectation of the math-foundations learning map.

The expected value of a random variable given the value of another (or given a sub-sigma-algebra); the foundation of regression and martingale theory.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Conditional Expectation (concept 27-conditional-expectation)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/27-conditional-expectation.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 30: Existence and Uniqueness (Picard-Lindelöf)
#
# **Prereqs:** 29-ode, 11-continuity
#
# Sufficient conditions (Lipschitz) under which an ODE has a unique solution; the foundation of well-posed dynamical systems.
#
# See `concepts/30-existence-uniqueness.md` for the full concept page.

# %%
"""Existence and Uniqueness (Picard-Lindelöf) — concept 30-existence-uniqueness of the math-foundations learning map.

Sufficient conditions (Lipschitz) under which an ODE has a unique solution; the foundation of well-posed dynamical systems.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Existence and Uniqueness (Picard-Lindelöf) (concept 30-existence-uniqueness)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/30-existence-uniqueness.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 31: Stochastic Processes
#
# **Prereqs:** 22-random-variables
#
# Indexed families of random variables; the time-evolution of randomness.
#
# See `concepts/31-stochastic-processes.md` for the full concept page.

# %%
"""Stochastic Processes — concept 31-stochastic-processes of the math-foundations learning map.

Indexed families of random variables; the time-evolution of randomness.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Stochastic Processes (concept 31-stochastic-processes)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/31-stochastic-processes.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 32: Brownian Motion / Wiener Process
#
# **Prereqs:** 31-stochastic-processes
#
# The canonical continuous-time stochastic process with independent Gaussian increments; the building block of stochastic calculus.
#
# See `concepts/32-brownian-motion.md` for the full concept page.

# %%
"""Brownian Motion / Wiener Process — concept 32-brownian-motion of the math-foundations learning map.

The canonical continuous-time stochastic process with independent Gaussian increments; the building block of stochastic calculus.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Brownian Motion / Wiener Process (concept 32-brownian-motion)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/32-brownian-motion.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 33: Stochastic Differential Equations
#
# **Prereqs:** 29-ode, 32-brownian-motion
#
# Differential equations driven by Brownian motion; the continuous-time analogue of random walks.
#
# See `concepts/33-sde.md` for the full concept page.

# %%
"""Stochastic Differential Equations — concept 33-sde of the math-foundations learning map.

Differential equations driven by Brownian motion; the continuous-time analogue of random walks.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Stochastic Differential Equations (concept 33-sde)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/33-sde.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Level: Frontier (information geometry + OT)

# %% [markdown]
# ### 34: Itô Calculus
#
# **Prereqs:** 33-sde
#
# The calculus of stochastic integrals where the integrator is non-smooth (Brownian); Itô's lemma replaces the chain rule.
#
# See `concepts/34-ito-calculus.md` for the full concept page.

# %%
"""Itô Calculus — concept 34-ito-calculus of the math-foundations learning map.

The calculus of stochastic integrals where the integrator is non-smooth (Brownian); Itô's lemma replaces the chain rule.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Itô Calculus (concept 34-ito-calculus)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/34-ito-calculus.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 40: Information Geometry (Fisher Metric)
#
# **Prereqs:** 38-kl-divergence, 14-gradient-jacobian
#
# Treats probability distributions as points on a Riemannian manifold; the Fisher information matrix as the natural metric tensor.
#
# See `concepts/40-information-geometry.md` for the full concept page.

# %%
"""Information Geometry (Fisher Metric) — concept 40-information-geometry of the math-foundations learning map.

Treats probability distributions as points on a Riemannian manifold; the Fisher information matrix as the natural metric tensor.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Information Geometry (Fisher Metric) (concept 40-information-geometry)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/40-information-geometry.md for the formal definition.")


if __name__ == "__main__":
    main()

# %% [markdown]
# ### 41: Optimal Transport (Wasserstein)
#
# **Prereqs:** 19-probability-measures, 09-norms-and-metrics
#
# Wasserstein distance W_p(mu, nu) = inf over couplings of E[|X - Y|^p]^(1/p); the cost of optimally moving one distribution to another. Provides a meaningful metric on distributions even when they have disjoint supports.
#
# See `concepts/41-optimal-transport.md` for the full concept page.

# %%
"""Optimal Transport (Wasserstein) — concept 41-optimal-transport of the math-foundations learning map.

Wasserstein distance W_p(mu, nu) = inf over couplings of E[|X - Y|^p]^(1/p); the cost of optimally moving one distribution to another. Provides a meaningful metric on distributions even when they have disjoint supports.

This is the auto-generated skeleton. Replace the body of main() with a
concrete, CPU-runnable demonstration of the concept (≤30 s, ≤80 lines).
For abstract concepts, implement a finite/discrete witness.
"""


def main():
    print("Optimal Transport (Wasserstein) (concept 41-optimal-transport)")
    print("=" * 60)
    print("TODO: implement a runnable demonstration of this concept.")
    print()
    print("See ../concepts/41-optimal-transport.md for the formal definition.")


if __name__ == "__main__":
    main()
