# %% [markdown]
# # Math Foundations — Aggregate Index
#
# This notebook is an index. Each concept has its own runnable notebook at
# `concepts/<NN>-<slug>/notebook.ipynb` — open those directly for cell-by-cell execution.

# %% [markdown]
# ## Level: Novice (high-school+)

# %% [markdown]
# ### 00: Sets and Functions
#
# **Prereqs:** (none)
#
# The two foundational objects: collections and rules that map elements between them.
#
# 📖 [README](../concepts/00-sets-and-functions/README.md)  ·  📓 [Notebook](../concepts/00-sets-and-functions/notebook.ipynb)  ·  💻 [Code](../concepts/00-sets-and-functions/code.py)  ·  📄 [Lesson PDF](../concepts/00-sets-and-functions/lesson.pdf)

# %% [markdown]
# ### 01: Logic and Proof
#
# **Prereqs:** 00-sets-and-functions
#
# Propositional and predicate logic, truth tables, the basic proof strategies (direct, contrapositive, contradiction, induction).
#
# 📖 [README](../concepts/01-logic-and-proof/README.md)  ·  📓 [Notebook](../concepts/01-logic-and-proof/notebook.ipynb)  ·  💻 [Code](../concepts/01-logic-and-proof/code.py)  ·  📄 [Lesson PDF](../concepts/01-logic-and-proof/lesson.pdf)

# %% [markdown]
# ### 02: Counting and Combinatorics
#
# **Prereqs:** 00-sets-and-functions
#
# Counting principles: permutations, combinations, the pigeonhole principle, inclusion-exclusion.
#
# 📖 [README](../concepts/02-counting/README.md)  ·  📓 [Notebook](../concepts/02-counting/notebook.ipynb)  ·  💻 [Code](../concepts/02-counting/code.py)  ·  📄 [Lesson PDF](../concepts/02-counting/lesson.pdf)

# %% [markdown]
# ### 03: Relations and Orderings
#
# **Prereqs:** 00-sets-and-functions
#
# Equivalence relations, partial and total orders, equivalence classes.
#
# 📖 [README](../concepts/03-relations-and-orderings/README.md)  ·  📓 [Notebook](../concepts/03-relations-and-orderings/notebook.ipynb)  ·  💻 [Code](../concepts/03-relations-and-orderings/code.py)  ·  📄 [Lesson PDF](../concepts/03-relations-and-orderings/lesson.pdf)

# %% [markdown]
# ## Level: Intermediate (calc + linear algebra)

# %% [markdown]
# ### 04: Groups, Rings, Fields
#
# **Prereqs:** 00-sets-and-functions, 01-logic-and-proof
#
# Abstract algebraic structures with binary operations satisfying axioms.
#
# 📖 [README](../concepts/04-groups-rings-fields/README.md)  ·  📓 [Notebook](../concepts/04-groups-rings-fields/notebook.ipynb)  ·  💻 [Code](../concepts/04-groups-rings-fields/code.py)  ·  📄 [Lesson PDF](../concepts/04-groups-rings-fields/lesson.pdf)

# %% [markdown]
# ### 05: Vector Spaces
#
# **Prereqs:** 04-groups-rings-fields
#
# Sets closed under linear combinations over a field; the universal object of linear algebra.
#
# 📖 [README](../concepts/05-vector-spaces/README.md)  ·  📓 [Notebook](../concepts/05-vector-spaces/notebook.ipynb)  ·  💻 [Code](../concepts/05-vector-spaces/code.py)  ·  📄 [Lesson PDF](../concepts/05-vector-spaces/lesson.pdf)

# %% [markdown]
# ### 06: Linear Maps and Matrices
#
# **Prereqs:** 05-vector-spaces
#
# Structure-preserving functions between vector spaces; the matrix representation.
#
# 📖 [README](../concepts/06-linear-maps/README.md)  ·  📓 [Notebook](../concepts/06-linear-maps/notebook.ipynb)  ·  💻 [Code](../concepts/06-linear-maps/code.py)  ·  📄 [Lesson PDF](../concepts/06-linear-maps/lesson.pdf)

# %% [markdown]
# ### 07: Eigenvalues and Eigenvectors
#
# **Prereqs:** 06-linear-maps
#
# Directions preserved by a linear map up to scaling; the building blocks of spectral analysis.
#
# 📖 [README](../concepts/07-eigenvalues/README.md)  ·  📓 [Notebook](../concepts/07-eigenvalues/notebook.ipynb)  ·  💻 [Code](../concepts/07-eigenvalues/code.py)  ·  📄 [Lesson PDF](../concepts/07-eigenvalues/lesson.pdf)

# %% [markdown]
# ### 08: Inner Product Spaces
#
# **Prereqs:** 05-vector-spaces
#
# Vector spaces equipped with a notion of angle and length via an inner product.
#
# 📖 [README](../concepts/08-inner-product-spaces/README.md)  ·  📓 [Notebook](../concepts/08-inner-product-spaces/notebook.ipynb)  ·  💻 [Code](../concepts/08-inner-product-spaces/code.py)  ·  📄 [Lesson PDF](../concepts/08-inner-product-spaces/lesson.pdf)

# %% [markdown]
# ### 09: Norms and Metrics
#
# **Prereqs:** 05-vector-spaces
#
# Generalised notions of distance; the foundation of analysis on vector spaces.
#
# 📖 [README](../concepts/09-norms-and-metrics/README.md)  ·  📓 [Notebook](../concepts/09-norms-and-metrics/notebook.ipynb)  ·  💻 [Code](../concepts/09-norms-and-metrics/code.py)  ·  📄 [Lesson PDF](../concepts/09-norms-and-metrics/lesson.pdf)

# %% [markdown]
# ## Level: Advanced (analysis + probability)

# %% [markdown]
# ### 10: Sequences and Limits
#
# **Prereqs:** 09-norms-and-metrics
#
# Convergence of sequences; the epsilon-N definition; Cauchy sequences and completeness.
#
# 📖 [README](../concepts/10-sequences-and-limits/README.md)  ·  📓 [Notebook](../concepts/10-sequences-and-limits/notebook.ipynb)  ·  💻 [Code](../concepts/10-sequences-and-limits/code.py)  ·  📄 [Lesson PDF](../concepts/10-sequences-and-limits/lesson.pdf)

# %% [markdown]
# ### 11: Continuity
#
# **Prereqs:** 10-sequences-and-limits
#
# The epsilon-delta definition; continuity as preservation of limits; uniform vs pointwise continuity.
#
# 📖 [README](../concepts/11-continuity/README.md)  ·  📓 [Notebook](../concepts/11-continuity/notebook.ipynb)  ·  💻 [Code](../concepts/11-continuity/code.py)  ·  📄 [Lesson PDF](../concepts/11-continuity/lesson.pdf)

# %% [markdown]
# ### 12: Derivatives (Univariate)
#
# **Prereqs:** 11-continuity
#
# The local linear approximation; the limit of a difference quotient; differentiation rules.
#
# 📖 [README](../concepts/12-derivatives/README.md)  ·  📓 [Notebook](../concepts/12-derivatives/notebook.ipynb)  ·  💻 [Code](../concepts/12-derivatives/code.py)  ·  📄 [Lesson PDF](../concepts/12-derivatives/lesson.pdf)

# %% [markdown]
# ### 13: Multivariate Calculus
#
# **Prereqs:** 12-derivatives
#
# Partial derivatives; the chain rule in multiple variables; directional derivatives.
#
# 📖 [README](../concepts/13-multivariate-calculus/README.md)  ·  📓 [Notebook](../concepts/13-multivariate-calculus/notebook.ipynb)  ·  💻 [Code](../concepts/13-multivariate-calculus/code.py)  ·  📄 [Lesson PDF](../concepts/13-multivariate-calculus/lesson.pdf)

# %% [markdown]
# ### 14: Gradient and Jacobian
#
# **Prereqs:** 13-multivariate-calculus, 06-linear-maps
#
# The gradient as the vector of partial derivatives; the Jacobian as the matrix of partial derivatives of a vector-valued function.
#
# 📖 [README](../concepts/14-gradient-jacobian/README.md)  ·  📓 [Notebook](../concepts/14-gradient-jacobian/notebook.ipynb)  ·  💻 [Code](../concepts/14-gradient-jacobian/code.py)  ·  📄 [Lesson PDF](../concepts/14-gradient-jacobian/lesson.pdf)

# %% [markdown]
# ### 15: Integration (Riemann)
#
# **Prereqs:** 11-continuity
#
# The Riemann integral as a limit of step-function approximations; the fundamental theorem of calculus.
#
# 📖 [README](../concepts/15-integration/README.md)  ·  📓 [Notebook](../concepts/15-integration/notebook.ipynb)  ·  💻 [Code](../concepts/15-integration/code.py)  ·  📄 [Lesson PDF](../concepts/15-integration/lesson.pdf)

# %% [markdown]
# ### 16: Series and Convergence
#
# **Prereqs:** 10-sequences-and-limits
#
# Convergence of infinite sums; absolute vs conditional; power series and Taylor expansions.
#
# 📖 [README](../concepts/16-series-and-convergence/README.md)  ·  📓 [Notebook](../concepts/16-series-and-convergence/notebook.ipynb)  ·  💻 [Code](../concepts/16-series-and-convergence/code.py)  ·  📄 [Lesson PDF](../concepts/16-series-and-convergence/lesson.pdf)

# %% [markdown]
# ### 17: Sample Spaces
#
# **Prereqs:** 00-sets-and-functions
#
# The set of all possible outcomes of an experiment; the starting point of probability.
#
# 📖 [README](../concepts/17-sample-spaces/README.md)  ·  📓 [Notebook](../concepts/17-sample-spaces/notebook.ipynb)  ·  💻 [Code](../concepts/17-sample-spaces/code.py)  ·  📄 [Lesson PDF](../concepts/17-sample-spaces/lesson.pdf)

# %% [markdown]
# ### 20: Conditional Probability
#
# **Prereqs:** 19-probability-measures
#
# P(A | B) = P(A and B) / P(B); the update rule for new information.
#
# 📖 [README](../concepts/20-conditional-probability/README.md)  ·  📓 [Notebook](../concepts/20-conditional-probability/notebook.ipynb)  ·  💻 [Code](../concepts/20-conditional-probability/code.py)  ·  📄 [Lesson PDF](../concepts/20-conditional-probability/lesson.pdf)

# %% [markdown]
# ### 21: Independence
#
# **Prereqs:** 20-conditional-probability
#
# P(A and B) = P(A) P(B); events that do not influence each other.
#
# 📖 [README](../concepts/21-independence/README.md)  ·  📓 [Notebook](../concepts/21-independence/notebook.ipynb)  ·  💻 [Code](../concepts/21-independence/code.py)  ·  📄 [Lesson PDF](../concepts/21-independence/lesson.pdf)

# %% [markdown]
# ### 22: Random Variables
#
# **Prereqs:** 19-probability-measures
#
# Measurable functions from the sample space to the real line; the bridge from sets-of-outcomes to numerical values.
#
# 📖 [README](../concepts/22-random-variables/README.md)  ·  📓 [Notebook](../concepts/22-random-variables/notebook.ipynb)  ·  💻 [Code](../concepts/22-random-variables/code.py)  ·  📄 [Lesson PDF](../concepts/22-random-variables/lesson.pdf)

# %% [markdown]
# ### 23: Probability Distributions
#
# **Prereqs:** 22-random-variables
#
# The full description of a random variable: its cumulative distribution function, its discrete probability mass function, or its continuous probability density function.
#
# 📖 [README](../concepts/23-distributions/README.md)  ·  📓 [Notebook](../concepts/23-distributions/notebook.ipynb)  ·  💻 [Code](../concepts/23-distributions/code.py)  ·  📄 [Lesson PDF](../concepts/23-distributions/lesson.pdf)

# %% [markdown]
# ### 24: Probability Density Functions
#
# **Prereqs:** 23-distributions, 15-integration
#
# A non-negative integrable function whose integral over a set gives the probability that a continuous random variable lands in that set.
#
# 📖 [README](../concepts/24-pdf/README.md)  ·  📓 [Notebook](../concepts/24-pdf/notebook.ipynb)  ·  💻 [Code](../concepts/24-pdf/code.py)  ·  📄 [Lesson PDF](../concepts/24-pdf/lesson.pdf)

# %% [markdown]
# ### 25: Expectation
#
# **Prereqs:** 23-distributions, 15-integration
#
# The weighted average of a random variable's values, weighted by their probability; the integral of the random variable against its distribution.
#
# 📖 [README](../concepts/25-expectation/README.md)  ·  📓 [Notebook](../concepts/25-expectation/notebook.ipynb)  ·  💻 [Code](../concepts/25-expectation/code.py)  ·  📄 [Lesson PDF](../concepts/25-expectation/lesson.pdf)

# %% [markdown]
# ### 26: Variance and Covariance
#
# **Prereqs:** 25-expectation
#
# Second-order moments measuring spread (variance) and linear association (covariance).
#
# 📖 [README](../concepts/26-variance-covariance/README.md)  ·  📓 [Notebook](../concepts/26-variance-covariance/notebook.ipynb)  ·  💻 [Code](../concepts/26-variance-covariance/code.py)  ·  📄 [Lesson PDF](../concepts/26-variance-covariance/lesson.pdf)

# %% [markdown]
# ### 28: Change of Variables (Probability)
#
# **Prereqs:** 24-pdf, 14-gradient-jacobian
#
# How densities transform under invertible smooth maps; the Jacobian determinant appears as the volume-correction factor.
#
# 📖 [README](../concepts/28-change-of-variables-probability/README.md)  ·  📓 [Notebook](../concepts/28-change-of-variables-probability/notebook.ipynb)  ·  💻 [Code](../concepts/28-change-of-variables-probability/code.py)  ·  📄 [Lesson PDF](../concepts/28-change-of-variables-probability/lesson.pdf)

# %% [markdown]
# ### 29: Ordinary Differential Equations
#
# **Prereqs:** 12-derivatives
#
# Equations relating a function to its derivatives; the basic objects of dynamical systems.
#
# 📖 [README](../concepts/29-ode/README.md)  ·  📓 [Notebook](../concepts/29-ode/notebook.ipynb)  ·  💻 [Code](../concepts/29-ode/code.py)  ·  📄 [Lesson PDF](../concepts/29-ode/lesson.pdf)

# %% [markdown]
# ### 35: Self-Information (Surprisal)
#
# **Prereqs:** 23-distributions
#
# I(x) = -log p(x); the surprise associated with observing an outcome under a probability distribution.
#
# 📖 [README](../concepts/35-self-information/README.md)  ·  📓 [Notebook](../concepts/35-self-information/notebook.ipynb)  ·  💻 [Code](../concepts/35-self-information/code.py)  ·  📄 [Lesson PDF](../concepts/35-self-information/lesson.pdf)

# %% [markdown]
# ### 36: Shannon Entropy
#
# **Prereqs:** 35-self-information, 25-expectation
#
# H(X) = E[-log p(X)]; the average information content of a random variable; measures uncertainty.
#
# 📖 [README](../concepts/36-shannon-entropy/README.md)  ·  📓 [Notebook](../concepts/36-shannon-entropy/notebook.ipynb)  ·  💻 [Code](../concepts/36-shannon-entropy/code.py)  ·  📄 [Lesson PDF](../concepts/36-shannon-entropy/lesson.pdf)

# %% [markdown]
# ### 37: Cross-Entropy
#
# **Prereqs:** 36-shannon-entropy
#
# H(p, q) = -E_p[log q]; the average code-length when using distribution q to encode samples drawn from p.
#
# 📖 [README](../concepts/37-cross-entropy/README.md)  ·  📓 [Notebook](../concepts/37-cross-entropy/notebook.ipynb)  ·  💻 [Code](../concepts/37-cross-entropy/code.py)  ·  📄 [Lesson PDF](../concepts/37-cross-entropy/lesson.pdf)

# %% [markdown]
# ### 38: KL Divergence
#
# **Prereqs:** 37-cross-entropy
#
# D_KL(p || q) = E_p[log p - log q]; the relative entropy / information gain in moving from q to p. Non-symmetric, non-metric.
#
# 📖 [README](../concepts/38-kl-divergence/README.md)  ·  📓 [Notebook](../concepts/38-kl-divergence/notebook.ipynb)  ·  💻 [Code](../concepts/38-kl-divergence/code.py)  ·  📄 [Lesson PDF](../concepts/38-kl-divergence/lesson.pdf)

# %% [markdown]
# ### 39: Mutual Information
#
# **Prereqs:** 38-kl-divergence, 21-independence
#
# I(X; Y) = D_KL(p(x,y) || p(x) p(y)); the reduction in uncertainty about X from observing Y.
#
# 📖 [README](../concepts/39-mutual-information/README.md)  ·  📓 [Notebook](../concepts/39-mutual-information/notebook.ipynb)  ·  💻 [Code](../concepts/39-mutual-information/code.py)  ·  📄 [Lesson PDF](../concepts/39-mutual-information/lesson.pdf)

# %% [markdown]
# ## Level: Graduate (measure theory + stochastic)

# %% [markdown]
# ### 18: Events and Sigma-Algebras
#
# **Prereqs:** 17-sample-spaces
#
# A sigma-algebra is a collection of subsets closed under complement and countable union; the rigorous basis for which events can be assigned probabilities.
#
# 📖 [README](../concepts/18-sigma-algebras/README.md)  ·  📓 [Notebook](../concepts/18-sigma-algebras/notebook.ipynb)  ·  💻 [Code](../concepts/18-sigma-algebras/code.py)  ·  📄 [Lesson PDF](../concepts/18-sigma-algebras/lesson.pdf)

# %% [markdown]
# ### 19: Probability Measures
#
# **Prereqs:** 18-sigma-algebras
#
# A function from a sigma-algebra to [0,1] satisfying countable additivity and P(Omega) = 1.
#
# 📖 [README](../concepts/19-probability-measures/README.md)  ·  📓 [Notebook](../concepts/19-probability-measures/notebook.ipynb)  ·  💻 [Code](../concepts/19-probability-measures/code.py)  ·  📄 [Lesson PDF](../concepts/19-probability-measures/lesson.pdf)

# %% [markdown]
# ### 27: Conditional Expectation
#
# **Prereqs:** 25-expectation, 20-conditional-probability
#
# The expected value of a random variable given the value of another (or given a sub-sigma-algebra); the foundation of regression and martingale theory.
#
# 📖 [README](../concepts/27-conditional-expectation/README.md)  ·  📓 [Notebook](../concepts/27-conditional-expectation/notebook.ipynb)  ·  💻 [Code](../concepts/27-conditional-expectation/code.py)  ·  📄 [Lesson PDF](../concepts/27-conditional-expectation/lesson.pdf)

# %% [markdown]
# ### 30: Existence and Uniqueness (Picard-Lindelöf)
#
# **Prereqs:** 29-ode, 11-continuity
#
# Sufficient conditions (Lipschitz) under which an ODE has a unique solution; the foundation of well-posed dynamical systems.
#
# 📖 [README](../concepts/30-existence-uniqueness/README.md)  ·  📓 [Notebook](../concepts/30-existence-uniqueness/notebook.ipynb)  ·  💻 [Code](../concepts/30-existence-uniqueness/code.py)  ·  📄 [Lesson PDF](../concepts/30-existence-uniqueness/lesson.pdf)

# %% [markdown]
# ### 31: Stochastic Processes
#
# **Prereqs:** 22-random-variables
#
# Indexed families of random variables; the time-evolution of randomness.
#
# 📖 [README](../concepts/31-stochastic-processes/README.md)  ·  📓 [Notebook](../concepts/31-stochastic-processes/notebook.ipynb)  ·  💻 [Code](../concepts/31-stochastic-processes/code.py)  ·  📄 [Lesson PDF](../concepts/31-stochastic-processes/lesson.pdf)

# %% [markdown]
# ### 32: Brownian Motion / Wiener Process
#
# **Prereqs:** 31-stochastic-processes
#
# The canonical continuous-time stochastic process with independent Gaussian increments; the building block of stochastic calculus.
#
# 📖 [README](../concepts/32-brownian-motion/README.md)  ·  📓 [Notebook](../concepts/32-brownian-motion/notebook.ipynb)  ·  💻 [Code](../concepts/32-brownian-motion/code.py)  ·  📄 [Lesson PDF](../concepts/32-brownian-motion/lesson.pdf)

# %% [markdown]
# ### 33: Stochastic Differential Equations
#
# **Prereqs:** 29-ode, 32-brownian-motion
#
# Differential equations driven by Brownian motion; the continuous-time analogue of random walks.
#
# 📖 [README](../concepts/33-sde/README.md)  ·  📓 [Notebook](../concepts/33-sde/notebook.ipynb)  ·  💻 [Code](../concepts/33-sde/code.py)  ·  📄 [Lesson PDF](../concepts/33-sde/lesson.pdf)

# %% [markdown]
# ## Level: Frontier (information geometry + OT)

# %% [markdown]
# ### 34: Itô Calculus
#
# **Prereqs:** 33-sde
#
# The calculus of stochastic integrals where the integrator is non-smooth (Brownian); Itô's lemma replaces the chain rule.
#
# 📖 [README](../concepts/34-ito-calculus/README.md)  ·  📓 [Notebook](../concepts/34-ito-calculus/notebook.ipynb)  ·  💻 [Code](../concepts/34-ito-calculus/code.py)  ·  📄 [Lesson PDF](../concepts/34-ito-calculus/lesson.pdf)

# %% [markdown]
# ### 40: Information Geometry (Fisher Metric)
#
# **Prereqs:** 38-kl-divergence, 14-gradient-jacobian
#
# Treats probability distributions as points on a Riemannian manifold; the Fisher information matrix as the natural metric tensor.
#
# 📖 [README](../concepts/40-information-geometry/README.md)  ·  📓 [Notebook](../concepts/40-information-geometry/notebook.ipynb)  ·  💻 [Code](../concepts/40-information-geometry/code.py)  ·  📄 [Lesson PDF](../concepts/40-information-geometry/lesson.pdf)

# %% [markdown]
# ### 41: Optimal Transport (Wasserstein)
#
# **Prereqs:** 19-probability-measures, 09-norms-and-metrics
#
# Wasserstein distance W_p(mu, nu) = inf over couplings of E[|X - Y|^p]^(1/p); the cost of optimally moving one distribution to another. Provides a meaningful metric on distributions even when they have disjoint supports.
#
# 📖 [README](../concepts/41-optimal-transport/README.md)  ·  📓 [Notebook](../concepts/41-optimal-transport/notebook.ipynb)  ·  💻 [Code](../concepts/41-optimal-transport/code.py)  ·  📄 [Lesson PDF](../concepts/41-optimal-transport/lesson.pdf)
